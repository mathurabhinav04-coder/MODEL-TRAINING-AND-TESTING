# %% [markdown]
# # **#import padas library**

# %%
import pandas as pd

# %%
# making df as a variable and reading the dataset
df=pd.read_csv('Titanic-Dataset.csv')

# %%
import os
print(os.getcwd)#folder path
print(os.listdir())#file names
# Out:
# <built-in function getcwd>
# ['.config', 'Titanic-Dataset.csv', 'sample_data']

# %%
#checkl the datset with the help of head
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(df.shape)
# Out:
# (891, 12)

# %%
# for full information of dataset use info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Fillling thedd null values
df['Age'].fillna(df['Age'].mean(),inplace=True)
# Out:
# /tmp/ipython-input-1861916889.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.Embarked.fillna(df.Embarked.mode()[0],inplace=True)
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
#print head and tail of dataset
df1=df.head(10)
df2=df.tail(5)

# %%
new_df=pd.merge(df1,df2,left_on="Survived",right_on="Survived",how="left")

# %%
new_df
# Out:
#     PassengerId_x  Survived  Pclass_x  \
# 0               1         0         3
# 1               1         0         3
# 2               1         0         3
# 3               2         1         1
# 4               2         1         1
# 5               3         1         3
# 6               3         1         3
# 7               4         1         1
# 8               4         1         1
# 9               5         0         3
# 10              5         0         3
# 11              5         0         3
# 12              6         0         3
# 13              6         0         3
# 14              6         0         3
# 15              7         0         1
# 16              7         0         1
# 17              7         0         1
# 18              8         0         3
# 19              8         0         3
# 20              8         0         3
# 21              9         1         3
# 22              9         1         3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
# convets textdata to number
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for col in["Sex","Embarked"]:
    df[col]=le.fit_transform(df[col].astype(str))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked
# 0         A/5 21171   7.2500   NaN         2
# 1          PC 17599  71.2833   C85         0
# 2  STON/O2. 3101282   7.9250   NaN         2
# 3            113803  53.1000  C123         2
# 4            373450   8.0500   NaN         2

# %%
#drop some of the heading
d=["Cabin"]
d=["Name"]
df.drop(d,axis=1,inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0            1         0       3    1  22.0      1      0         A/5 21171
# 1            2         1       1    0  38.0      1      0          PC 17599
# 2            3         1       3    0  26.0      0      0  STON/O2. 3101282
# 3            4         1       1    0  35.0      1      0            113803
# 4            5         0       3    1  35.0      0      0            373450
#
#       Fare  Embarked
# 0   7.2500         2
# 1  71.2833         0
# 2   7.9250         2
# 3  53.1000         2
# 4   8.0500         2

# %%
print(df.shape)
# Out:
# (891, 10)

# %%
df.rename(columns={"Sex":"Gender", "PassengerId":"P_ID", "Ticket":"Tic"},inplace=True)

# %%
df.head()
# Out:
#    P_ID  Survived  Pclass  Gender   Age  SibSp  Parch               Tic  \
# 0     1         0       3       1  22.0      1      0         A/5 21171
# 1     2         1       1       0  38.0      1      0          PC 17599
# 2     3         1       3       0  26.0      0      0  STON/O2. 3101282
# 3     4         1       1       0  35.0      1      0            113803
# 4     5         0       3       1  35.0      0      0            373450
#
#       Fare  Embarked
# 0   7.2500         2
# 1  71.2833         0
# 2   7.9250         2
# 3  53.1000         2
# 4   8.0500         2

# %% [markdown]
# # **Feature engineering**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.countplot(x="Survived",data=df)
plt.title("Survived")
plt.show()

# %% [markdown]
# # **TAIN AND TEST THE DATASET **

# %%
dat=["Pclass","Age","SibSp","Parch","Fare","Gender","Embarked"]
x=df[dat]
y=df["Survived"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((712, 7), (179, 7))

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
y_pred=lr.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8100558659217877

# %%
from sklearn.tree import DecisionTreeClassifier
lr=DecisionTreeClassifier()
lr.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.metrics import accuracy_score
y_pred=lr.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.770949720670391

# %%
from sklearn.neighbors import KNeighborsClassifier
lr=KNeighborsClassifier()
lr.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score
y_pred=lr.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.7150837988826816

# %%
from sklearn.ensemble import RandomForestClassifier
lr=RandomForestClassifier()
lr.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score
y_pred=lr.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8212290502793296
